# %% [markdown]
# ## 06 - Lines and Distances
#
# ### Goal
#
# - Last lesson we loaded the WDO package and used some of the given spatial functions. Now we are going to put package to use and calculate many distances and draw some lines.
# - Using any file that has "world cities" in the name:
#
#   - [WorldCitiesGeo](../data/WorldCitiesGeo/) (and all its geojson files in the directory)
#   - [world_cities_fixed.json](../data/world_cities_fixed.json)
#   - [world_cities_by_time-zone.json](../data/world_cities_by_time-zone.json)
#
# - These contain ALL THE CITIES IN THE WORLD! Well ... most of the cities.  You know like the ones that ... have people.  I mean `Burkburnett` probably isn't in the file, but it does have people, so ... (update ... I just checked, and Burk is in the file!)
#
# - Keep reading
#
#
# ### Tasks
#
# - Read in a file containing the locations to cities all over the world ([world_cities_large.json](./../data/world_cities_large.json)).
# - We would like to draw a line from MSU (or close to it) to each city in the file, but thats not feasible as the file is too large.
# - Looking at the options (files) above, you should have plenty of choices for filtering down to a manageable size of cities to draw lines to.

# %% [markdown]
# ## Possible Bonus
#
# - Randomly choose cities from the file, and stop choosing when the distance goes over some threshold (e.g 10000km).

# %%
from pathlib import Path


## Use last items learned from last lesson to locate and check if the file exists 
## Remember parent, and folder: data

# ----------------------------------------
# Distance: Haversine (km)
# ----------------------------------------
from math import radians, sin, cos, sqrt, atan2
EARTH_RADIUS_KM = 6371
def haversine_km(lat1: float, lon1: float, lat2: float, lon2: float) -> float:
    """
    Compute great-circle distance between two lat/lon points.
    Returns distance in kilometers.
    Inputs: degrees
    Output: kilometers
    """
    phi1 = radians(lat1)
    phi2 = radians(lat2)

    dphi = radians(lat2 - lat1)
    dlmb = radians(lon2 - lon1)

    a = sin(dphi / 2) ** 2 + cos(phi1) * cos(phi2) * sin(dlmb / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return EARTH_RADIUS_KM * c



debug = False

cwd = Path.cwd()
if debug: 
    print("Current Working Directory:")
    print(cwd)

target = Path.cwd().parent / "data" / "world_cities_fixed.json"
if debug: 
    print("\nAttempting to access:")
    print(target)

exists = target.exists()
if debug: 
    print("\nDoes file exist?")
    print(exists)

assert exists, (
    f"\n❌ ERROR: File not found:\n{target}\n"
    "Check spelling and folder structure."
)

# %% [markdown]
# **FYI:**
#
# These previous three lessons will be helpful:
# - [03-Style_W_Logic](./03-Style_W_Logic.ipynb)
# - [04-Distance](./04-Distance.ipynb)
# - [05-Geo_and_Json_overview](./05-Geo_and_Json_overview.ipynb)

# %%
import json
import folium
from pathlib import Path

msu = {
    "name": "MSU",
    "lat": 33.87372,
    "lon": -98.51947
}

target = Path.cwd().parent / "data" / "world_cities_fixed.json"

with open(target, "r") as f:
    cities = json.load(f)

m = folium.Map(location=[msu["lat"], msu["lon"]], zoom_start=3)

folium.Marker(
    [msu["lat"], msu["lon"]],
    popup="MSU"
).add_to(m)

count = 0

for city in cities[:50]:
    city_lat = float(city["lat"])
    city_lon = float(city["lon"])

    distance = haversine_km(msu["lat"], msu["lon"], city_lat, city_lon)

    folium.PolyLine(
        [[msu["lat"], msu["lon"]], [city_lat, city_lon]],
        popup=f"{city['city-name']}: {distance:.2f} km",
        color="blue",
        weight=1
    ).add_to(m)

    count += 1

print("Lines created:", count)

m
# Out:
# Lines created: 50
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14ff6b6df9e11009a4e8864f01635101 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14ff6b6df9e11009a4e8864f01635101&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14ff6b6df9e11009a4e8864f01635101 = L.map(
#                 &quot;map_14ff6b6df9e11009a4e8864f01635101&quot;,
#                 {
#                     center: [33.87372, -98.51947],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab7bf4fa5054e817b455a9e1fda33257 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab7bf4fa5054e817b455a9e1fda33257.addTo(map_14ff6b6df9e11009a4e8864f01635101);
#
#
#             var marker_3d2948e61852a9d3792874638af868b9 = L.marker(
#                 [33.87372, -98.51947],
#                 {
# }
#             ).addTo(map_14ff6b6df9e11009a4e8864f01635101);
#
#
#         var popup_8107e5a124061cdf642d9b21a9bc90be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0aacf719f2354bde864add9c0656491 = $(`&lt;div id=&quot;html_a0aacf719f2354bde864add9c0656491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MSU&lt;/div&gt;`)[0];
#                 popup_8107e5a124061cdf642d9b21a9bc90be.setContent(html_a0aacf719f2354bde864add9c0656491);
#
#
#
#         marker_3d2948e61852a9d3792874638af868b9.bindPopup(popup_8107e5a124061cdf642d9b21a9bc90be)
#         ;
#
#
#
#
#             var poly_line_59a8e0555ff6d82782296f5c94645607 = L.polyline(
#                 [[33.87372, -98.51947], [42.57952, 1.65362]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_14ff6b6df9e11009a4e8864f01635101);
#
#
#         var popup_4f64e35ea3b12766d033fa6d775133df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2625c7dff7a431f9f62a1d8736e213d1 = $(`&lt;div id=&quot;html_2625c7dff7a431f9f62a1d8736e213d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Tarter: 8271.44 km&lt;/div&gt;`)[0];
#                 popup_4f64e35ea3b12766d033fa6d775133df.setContent(html_2625c7dff7a431f9f62a1d8736e213d1);
#
#
#
#         poly_line_59a8e0555ff6d82782296f5c94645607.bindPopup(popup_4f64e35ea3b12766d033fa6d775133df)
#         ;
#
#
#
#
#             var poly_line_a48e57249c4e4d407a1272ab8fef74fe = L.polyline(
#                 [[33.87372, -98.51947], [42.46372, 1.49129]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_14ff6b6df9e11009a4e8864f01635101);
#
#
#         var popup_8ab5db87523f6f5cb628d3a20b5325f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_479a8a73b51c6123ca1f454ec2c38f39 = $(`&lt;div id=&quot;html_479a8a73b51c6123ca1f454ec2c38f39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sant Julia de Loria: 8266.96 km&lt;/div&gt;`)[0];
#                 popup_8ab5db87523f6f5cb628d3a20b5325f2.setContent(html_479a8a73b51c6123ca1f454ec2c38f39);
#
#
#
#         poly_line_a48e57249c4e4d407a1272ab8fef74fe.bindPopup(popup_8ab5db87523f6f5cb628d3a20b5325f2)
#         ;
#
#
#
#
#             var poly_line_b14d2173056ba00dccccfefc6b87916d = L.polyline(
#                 [[33.87372, -98.51947], [42.54277, 1.73361]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&q

# %% [markdown]
# This lesson helps with **📏 Milestone 2**
