# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
# 📝 Sample file read
with open('sample.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# Python is very easy to learn
# Hi
# I like programming in Python
# Good morning
# I love my dog

# %%
# 🔍 Process each line
with open('sample.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['Python is very easy to learn']
# Parts: ['Hi']
# Parts: ['I like programming in Python']
# Parts: ['Good morning']
# Parts: ['I love my dog']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
# Tip: use `len(line.split()) > 3` to check
with open('sample.txt', 'r') as file:
    for line in file:
        if len(line.split()) > 3:
            print(line.strip())
# Out:
# Python is very easy to learn
# I like programming in Python
# I love my dog
