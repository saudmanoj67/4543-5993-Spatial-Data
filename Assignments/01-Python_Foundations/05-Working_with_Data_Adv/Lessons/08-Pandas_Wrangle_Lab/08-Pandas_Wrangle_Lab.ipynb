# %% [markdown]
# # 🧪 Pandas Wrangle Lab: Clean & Explore a Real Dataset
#
# ## 🔹 LEARNING GOALS:
# - Practice loading, cleaning, and exploring real-world data
# - Apply column creation, renaming, sorting, and filtering
# - Use `.info()`, `.describe()`, and `.query()` fluently

# %% [markdown]
# ### 📥 1. Load the Dataset

# %%
import pandas as pd
df = pd.read_csv("../../data/students.csv")
df.head()
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE GRADE  NAME_LENGTH  \
# 0      Alice     Smith    85       88           86.5     B            5
# 1        Bob     Jones    90       85           87.5     B            3
# 2    Charlie     Brown    78       82           80.0     B            7
# 3      David    Wilson    92       95           93.5     A            5
#
#    MATH_PLUS_5
# 0           90
# 1           95
# 2           83
# 3           97

# %% [markdown]
# ### 🔎 2. Inspect and Audit the Data

# %%
# Basic overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIRST_NAME     4 non-null      object
#  1   LAST_NAME      4 non-null      object
#  2   MATH           4 non-null      int64
#  3   SCIENCE        4 non-null      int64
#  4   AVERAGE_SCORE  4 non-null      float64
#  5   GRADE          4 non-null      object
#  6   NAME_LENGTH    4 non-null      int64
#  7   MATH_PLUS_5    4 non-null      int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 384.0+ bytes

# %%
# Summary stats
df.describe()
# Out:
#             MATH    SCIENCE  AVERAGE_SCORE  NAME_LENGTH  MATH_PLUS_5
# count   4.000000   4.000000       4.000000     4.000000     4.000000
# mean   86.250000  87.500000      86.875000     5.000000    91.250000
# std     6.238322   5.567764       5.528336     1.632993     6.238322
# min    78.000000  82.000000      80.000000     3.000000    83.000000
# 25%    83.250000  84.250000      84.875000     4.500000    88.250000
# 50%    87.500000  86.500000      87.000000     5.000000    92.500000
# 75%    90.500000  89.750000      89.000000     5.500000    95.500000
# max    92.000000  95.000000      93.500000     7.000000    97.000000

# %% [markdown]
# ### 🧼 3. Clean Missing or Invalid Data

# %%
# Check for missing values
df.isnull().sum()
# Out:
# FIRST_NAME       0
# LAST_NAME        0
# MATH             0
# SCIENCE          0
# AVERAGE_SCORE    0
# GRADE            0
# NAME_LENGTH      0
# MATH_PLUS_5      0
# dtype: int64

# %%
# Drop rows with missing names
df.dropna(subset=["FIRST_NAME", "LAST_NAME"], inplace=True)

df["MATH"] = df["MATH"].fillna(df["MATH"].mean())
df["SCIENCE"] = df["SCIENCE"].fillna(df["SCIENCE"].mean())

# %% [markdown]
# ### 🧠 4. Feature Engineering (New Columns)

# %%
# Add average and grade
df["AVERAGE_SCORE"] = (df["MATH"] + df["SCIENCE"]) / 2

def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "D"

df["GRADE"] = df["AVERAGE_SCORE"].apply(grade)

df.head()
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE GRADE  NAME_LENGTH  \
# 0      Alice     Smith    85       88           86.5     B            5
# 1        Bob     Jones    90       85           87.5     B            3
# 2    Charlie     Brown    78       82           80.0     B            7
# 3      David    Wilson    92       95           93.5     A            5
#
#    MATH_PLUS_5
# 0           90
# 1           95
# 2           83
# 3           97

# %% [markdown]
# ### 🔽 5. Sorting and Filtering

# %%
df[df["AVERAGE_SCORE"] > 90].sort_values(by="AVERAGE_SCORE", ascending=False).head()
# Out:
#   FIRST_NAME LAST_NAME  MATH  SCIENCE  AVERAGE_SCORE GRADE  NAME_LENGTH  \
# 3      David    Wilson    92       95           93.5     A            5
#
#    MATH_PLUS_5
# 3           97

# %% [markdown]
# ### 📊 6. Group and Describe by Grade

# %%
# How many of each grade?
df["GRADE"].value_counts()
# Out:
# GRADE
# B    3
# A    1
# Name: count, dtype: int64

# %%
# Average scores per grade group
df.groupby("GRADE")[["MATH", "SCIENCE", "AVERAGE_SCORE"]].mean()
# Out:
#             MATH  SCIENCE  AVERAGE_SCORE
# GRADE
# A      92.000000     95.0      93.500000
# B      84.333333     85.0      84.666667

# %% [markdown]
# ### 💾 7. Save the Cleaned Dataset

# %%
df.to_csv("student_scores_cleaned.csv", index=False)

# %% [markdown]
# ### 🧠 Challenge Task
#
# > Your turn! Filter out students who got a D, sort by last name, and export to a new file:
# - Only include columns: `first_name`, `last_name`, `grade`
# - Save it as `"d_students.csv"`

# %%
# Filter D students
d_students = df[df["GRADE"] == "D"]

# Sort by last name
d_students = d_students.sort_values(by="LAST_NAME")

# Select only required columns
d_students = d_students[["FIRST_NAME", "LAST_NAME", "GRADE"]]

# Save file
d_students.to_csv("d_students.csv", index=False)

print(d_students)

print("\nd_students.csv saved!")
# Out:
# Empty DataFrame
# Columns: [FIRST_NAME, LAST_NAME, GRADE]
# Index: []
#
# d_students.csv saved!

# %% [markdown]
# ### 📝 Summary
#
# This lab gave you hands-on experience with:
# - Cleaning nulls and type mismatches
# - Creating new columns
# - Filtering and sorting real data
# - Grouping and summarizing by categorical features
#
# Your data wrangling toolbox is now ready for real-world messiness. 🧹🛠️
